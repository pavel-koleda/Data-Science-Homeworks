# %%
import pandas as pd
from matplotlib import pyplot as plt
import seaborn as sns
# %matplotlib inline
import numpy as np
from sklearn.metrics import confusion_matrix, precision_score, \
              recall_score, f1_score, precision_recall_curve, roc_curve, roc_auc_score, \
              auc, mean_squared_error, accuracy_score
import math
plt.rcParams["figure.figsize"] = (12,6)
from sklearn.model_selection import cross_val_score

# %% [markdown]
# # SK-learn

# %% [markdown]
# ## Bagging

# %%
from sklearn.model_selection import train_test_split
from sklearn.datasets import make_moons

X, y = make_moons(n_samples=500, noise=0.3, random_state=42)
X_train, X_test, y_train, y_test = train_test_split(X, y, random_state=42)

# %%
plt.scatter(X[y==0, 0], X[y==0, 1], color = (0,1,0))
plt.scatter(X[y==1, 0], X[y==1, 1], color = (1,0,0));

# %%
from sklearn.ensemble import BaggingClassifier
from sklearn.tree import DecisionTreeClassifier
from sklearn.linear_model import LogisticRegression

bag_clf = BaggingClassifier(
    LogisticRegression(random_state=42), n_estimators=100,
    max_samples=100, bootstrap=True, n_jobs=-1, random_state=42)
bag_clf.fit(X_train, y_train)
y_pred = bag_clf.predict(X_test)

# %%
print(accuracy_score(y_test, y_pred))
# Out:
# 0.848

# %%
tree_clf = DecisionTreeClassifier(random_state=42)
tree_clf.fit(X_train, y_train)
y_pred_tree = tree_clf.predict(X_test)
print(accuracy_score(y_test, y_pred_tree))
# Out:
# 0.856

# %% [markdown]
# ## Оценка на неиспользуемых образцах

# %%
df = pd.read_csv('churn-bigml-80.csv')
test_df = pd.read_csv('churn-bigml-20.csv')

# %%
df['International plan'] = df['International plan'].map({'No':0, 'Yes':1})
df['Voice mail plan'] = df['Voice mail plan'].map({'No':0, 'Yes':1})
X = df.drop(['State', 'Churn'], axis = 1)
Y = df['Churn']

test_df['International plan'] = test_df['International plan'].map({'No':0, 'Yes':1})
test_df['Voice mail plan'] = test_df['Voice mail plan'].map({'No':0, 'Yes':1})
X_test = test_df.drop(['State', 'Churn'], axis = 1)
Y_test = test_df['Churn']

# %%
bag_clf = BaggingClassifier(
    DecisionTreeClassifier(random_state=42), n_estimators=500,
    max_samples=0.3, bootstrap=True, oob_score = True, n_jobs=-1, random_state=42)
bag_clf.fit(X, Y)
# Out:
# BaggingClassifier(base_estimator=DecisionTreeClassifier(random_state=42),
#                   max_samples=0.3, n_estimators=500, n_jobs=-1, oob_score=True,
#                   random_state=42)

# %%
bag_clf.oob_score_
# Out:
# 0.9508627156789198

# %%
pred = bag_clf.predict(X_test)
accuracy_score (Y_test, pred)
# Out:
# 0.9550224887556222

# %% [markdown]
# ## Метод случайных участков

# %%
bag_clf = BaggingClassifier(
    DecisionTreeClassifier(random_state=42), n_estimators=500,
    max_samples=0.3, bootstrap=True, oob_score = True, n_jobs=-1, random_state=42,
    bootstrap_features = True, max_features = 1)


bag_clf.fit(X, Y)
# Out:
# BaggingClassifier(base_estimator=DecisionTreeClassifier(random_state=42),
#                   bootstrap_features=True, max_features=1, max_samples=0.3,
#                   n_estimators=500, n_jobs=-1, oob_score=True, random_state=42)

# %%
bag_clf.oob_score_
# Out:
# 0.854463615903976

# %% [markdown]
# ## Метод случайных подпространств

# %%
bag_clf = BaggingClassifier(
    DecisionTreeClassifier(random_state=42), n_estimators=500,
    max_samples=1, bootstrap=False, n_jobs=-1, random_state=42,
    bootstrap_features = True, max_features = 0.6)

bag_clf.fit(X, Y)
# Out:
# BaggingClassifier(base_estimator=DecisionTreeClassifier(random_state=42),
#                   bootstrap=False, bootstrap_features=True, max_features=0.6,
#                   max_samples=1, n_estimators=500, n_jobs=-1, random_state=42)

# %%
pred = bag_clf.predict(X_test)
accuracy_score (Y_test, pred)
# Out:
# 0.8575712143928036

# %% [markdown]
# ## Случайный лес

# %%
from sklearn.ensemble import RandomForestClassifier

rnd_clf = RandomForestClassifier(n_estimators=500,
                                 max_depth = 5,
                                 n_jobs=-1, random_state=42)
rnd_clf.fit(X, Y)

y_pred_rf = rnd_clf.predict(X_test)

# %%
print(accuracy_score(Y_test, y_pred_rf))
# Out:
# 0.9235382308845578

# %%
# Метод подпространств
rnd_clf = RandomForestClassifier(n_estimators=500,
                                 max_leaf_nodes = 16, 
                                 bootstrap=False, max_features=0.6,
                                 max_samples=1,
                                 n_jobs=-1, random_state=42)
rnd_clf.fit(X, Y)
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# ~\AppData\Local\Temp\ipykernel_24308\768398756.py in <module>
#       5                                  max_samples=1,
#       6                                  n_jobs=-1, random_state=42)
# ----> 7 rnd_clf.fit(X, Y)
#
# D:\anaconda3\lib\site-packages\sklearn\ensemble\_forest.py in fit(self, X, y, sample_weight)
#     377
#     378         if not self.bootstrap and self.max_samples is not None:
# --> 379             raise ValueError(
#     380                 "`max_sample` cannot be set if `bootstrap=False`. "
#     381                 "Either switch to `bootstrap=True` or set "
#
# ValueError: `max_sample` cannot be set if `bootstrap=False`. Either switch to `bootstrap=True` or set `max_sample=None`.

# %%
y_pred_rf = rnd_clf.predict(X_test)
print(accuracy_score(Y_test, y_pred_rf))
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# ~\AppData\Local\Temp\ipykernel_24308\2192756892.py in <module>
# ----> 1 y_pred_rf = rnd_clf.predict(X_test)
#       2 print(accuracy_score(Y_test, y_pred_rf))
#
# D:\anaconda3\lib\site-packages\sklearn\ensemble\_forest.py in predict(self, X)
#     806             The predicted classes.
#     807         """
# --> 808         proba = self.predict_proba(X)
#     809
#     810         if self.n_outputs_ == 1:
#
# D:\anaconda3\lib\site-packages\sklearn\ensemble\_forest.py in predict_proba(self, X)
#     865         )(
#     866             delayed(_accumulate_prediction)(e.predict_proba, X, all_proba, lock)
# --> 867             for e in self.estimators_
#     868         )
#     869
#
# AttributeError: 'RandomForestClassifier' object has no attribute 'estimators_'

# %%
# BONUS Значимость признаков
for name, score in zip(X.columns.tolist(), rnd_clf.feature_importances_):
    print(name, score)
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# ~\AppData\Local\Temp\ipykernel_24308\2314068693.py in <module>
#       1 # BONUS Значимость признаков
# ----> 2 for name, score in zip(X.columns.tolist(), rnd_clf.feature_importances_):
#       3     print(name, score)
#
# D:\anaconda3\lib\site-packages\sklearn\ensemble\_forest.py in feature_importances_(self)
#     609         )(
#     610             delayed(getattr)(tree, "feature_importances_")
# --> 611             for tree in self.estimators_
#     612             if tree.tree_.node_count > 1
#     613         )
#
# AttributeError: 'RandomForestClassifier' object has no attribute 'estimators_'

# %% [markdown]
# ## BOOSTING

# %%
from sklearn.preprocessing import StandardScaler

# %%
sc = StandardScaler()
X_sc = sc.fit_transform(X)

# %%
X_sc
# Out:
# array([[ 0.69216332, -0.52781119, -0.33569005, ..., -0.59752673,
#         -0.08568137, -0.42917241],
#        [ 0.16127783, -0.52781119, -0.33569005, ..., -0.59752673,
#          1.24292063, -0.42917241],
#        [ 0.91968567, -0.52781119, -0.33569005, ...,  0.21689365,
#          0.69819381, -1.19195484],
#        ...,
#        [-0.82465237, -0.52781119, -0.33569005, ..., -0.19031654,
#         -0.23182759,  1.09639245],
#        [-1.83586283,  1.70679716, -0.33569005, ...,  0.62410384,
#          1.38906685,  0.33361002],
#        [-0.6729708 , -0.52781119, -0.33569005, ..., -0.19031654,
#          1.24292063, -1.19195484]])

# %%
# ADA BOOST
from sklearn.svm import SVC
from sklearn.ensemble import AdaBoostClassifier

ada_clf = AdaBoostClassifier(
    SVC(), n_estimators=50, # как правило деревья а не SVC (случайный лес много не даст но будет долго считать)
    algorithm="SAMME",
    learning_rate=0.5, random_state=42)
ada_clf.fit(X_sc, Y)#algorithm="SAMME.R"
# Out:
# AdaBoostClassifier(algorithm='SAMME', base_estimator=SVC(), learning_rate=0.5,
#                    random_state=42)

# %%
X_sc_test = sc.transform(X_test)
y_pred_rf = ada_clf.predict(X_sc_test)
print(accuracy_score(Y_test, y_pred_rf))
# Out:
# 0.8575712143928036

# %%
X
# Out:
#       Account length  Area code  International plan  Voice mail plan  \
# 0                128        415                   0                1
# 1                107        415                   0                1
# 2                137        415                   0                0
# 3                 84        408                   1                0
# 4                 75        415                   1                0
# ...              ...        ...                 ...              ...
# 2661              79        415                   0                0
# 2662             192        415                   0                1
# 2663              68        415                   0                0
# 2664              28        510                   0                0
# 2665              74        415                   0                1
#
#       Number vmail messages  Total day minutes  Total day calls  \
# 0                        25              265.1              110
# 1                        26              161.6              123
# 2                         0              243.4              114
# 3                         0              299.4               71
# 4                         0              166.7              113
# ...                     ...                ...              ...
# 2661                      0              134.7               98
# 2662                     36              156.2               77
# 2663                      0              231.1               57
# 2664                      0              180.8              109
# 2665                     25              234.4              113
#
#       Total day charge  Total eve minutes  Total eve calls  Total eve charge  \
# 0                45.07              197.4               99             16.78
# 1                27.47              195.5              103             16.62
# 2                41.38              121.2              110             10.30
# 3                50.90               61.9               88              5.26
# 4                28.34              148.3              122             12.61
# ...                ...                ...              ...               ...
# 2661             22.90              189.7               68             16.12
# 2662             26.55              215.5              126             18.32
# 2663             39.29              153.4               55             13.04
# 2664             30.74              288.8               58             24.55
# 2665             39.85              265.9               82             22.60
#
#       Total night minutes  Total night calls  Total night charge  \
# 0                   244.7                 91               11.01
# 1                   254.4                103               11.45
# 2                   162.6                104                7.32
# 3                   196.9                 89                8.86
# 4                   186.9                121                8.41
# ...                   ...                ...                 ...
# 2661                221.4                128                9.96
# 2662                279.1                 83               12.56
# 2663                191.3                123                8.61
# 2664                191.9                 91                8.64
# 2665                241.4                 77               10.86
#
#       Total intl minutes  Total intl calls  Total intl charge  \
# 0                   10.0                 3               2.70
# 1                   13.7                 3               3.70
# 2                   12.2                 5               3.29
# 3                    6.6                 7               1.78
# 4                   10.1                 3               2.73
# ...                  ...               ...                ...
# 2661                11.8                 5               3.19
# 2662                 9.9                 6               2.67
# 2663                 9.6                 4               2.59
# 2664                14.1                 6               3.81
# 2665                13.7                 4               3.70
#
#       Customer service calls
# 0                          1
# 1                          1
# 2                          0
# 3                          2
# 4                          3
# ...                      ...
# 2661                       2
# 2662                       2
# 2663                       3
# 2664                       2
# 2665                       0
#
# [2666 rows x 18 columns]

# %%
# GradientBoosting
# сгенерируем данные
np.random.seed(42)
X = np.random.rand(100, 1) - 0.5
y = 3*X[:, 0]**2 + 0.05 * np.random.randn(100)

# %%
plt.scatter(X,y)

# %%
from sklearn.tree import DecisionTreeRegressor

tree_reg1 = DecisionTreeRegressor(max_depth=2, random_state=42)
tree_reg1.fit(X, y)
# Out:
# DecisionTreeRegressor(max_depth=2, random_state=42)

# %%
y2 = y - tree_reg1.predict(X)
tree_reg2 = DecisionTreeRegressor(max_depth=2, random_state=42)
tree_reg2.fit(X, y2)
# Out:
# DecisionTreeRegressor(max_depth=2, random_state=42)

# %%
plt.scatter(X,y2)

# %%
y3 = y2 - tree_reg2.predict(X)
tree_reg3 = DecisionTreeRegressor(max_depth=2, random_state=42)
tree_reg3.fit(X, y3)
# Out:
# DecisionTreeRegressor(max_depth=2, random_state=42)

# %%
plt.scatter(X,y3)

# %%
X_new = np.array([[0.8]])

# %%
y_pred = sum(tree.predict(X_new) for tree in (tree_reg1, tree_reg2, tree_reg3))
y_pred
# Out:
# array([0.75026781])

# %%
# Вернемся к отлюченцам
df = pd.read_csv('churn-bigml-80.csv')
test_df = pd.read_csv('churn-bigml-20.csv')
df['International plan'] = df['International plan'].map({'No':0, 'Yes':1})
df['Voice mail plan'] = df['Voice mail plan'].map({'No':0, 'Yes':1})
X = df.drop(['State', 'Churn'], axis = 1)
Y = df['Churn']

test_df['International plan'] = test_df['International plan'].map({'No':0, 'Yes':1})
test_df['Voice mail plan'] = test_df['Voice mail plan'].map({'No':0, 'Yes':1})
X_test = test_df.drop(['State', 'Churn'], axis = 1)
Y_test = test_df['Churn']

# %%
from sklearn.ensemble import GradientBoostingClassifier

# %%
gbc = GradientBoostingClassifier(n_estimators = 200,
                                max_depth = 4,
                                random_state = 15)
gbc.fit(X,Y)
# Out:
# GradientBoostingClassifier(max_depth=4, n_estimators=200, random_state=15)

# %%
pred = gbc.predict(X_test)
accuracy_score(Y_test, pred)
# Out:
# 0.952023988005997

# %%
cross_val_score (gbc, X,Y, cv = 5,)
# Out:
# array([0.95318352, 0.94746717, 0.95309568, 0.95497186, 0.95497186])
